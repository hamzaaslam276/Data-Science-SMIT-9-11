# %% [markdown]
# # Histogram Plot in Matplotlib

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import random

# %%
x = np.random.randint(10,100,(50))
print(x)
# Out:
# [48 67 35 46 30 93 60 29 67 94 16 26 67 48 39 88 38 25 71 15 94 88 77 67
#  84 75 14 18 92 82 34 47 48 90 42 82 72 70 79 69 45 65 81 24 45 76 46 18
#  67 72]

# %%
y = [48, 67, 35, 46, 30, 93, 60, 29, 67, 94, 16, 26, 67, 48, 39, 88, 38, 25, 71, 15, 94, 88, 77, 67,
 84, 75, 14, 18, 92, 82, 34, 47, 48, 90, 42, 82, 72, 70, 79, 69, 45, 65, 81, 24, 45, 76, 46, 18,
 67, 72,]
plt.xlabel("Python",fontsize=15)
plt.ylabel("No.",fontsize=15)
l = (10,20,30,40,50,60,70,80,90)
plt.title("Histogram Plot in Matplotlib",fontsize=15)
plt.hist(y,color='r',log='bool',align='left',rwidth=0.9,bins=l,label='Python')
plt.legend()
plt.show()

# %%
y = [48, 67, 35, 46, 30, 93, 60, 29, 67, 94, 16, 26, 67, 48, 39, 88, 38, 25, 71, 15, 94, 88, 77, 67,
 84, 75, 14, 18, 92, 82, 34, 47, 48, 90, 42, 82, 72, 70, 79, 69, 45, 65, 81, 24, 45, 76, 46, 18,
 67, 72,]
plt.xlabel("Python",fontsize=15)
plt.ylabel("No.",fontsize=15)
l = (10,20,30,40,50,60,70,80,90)
plt.title("Histogram Plot in Matplotlib",fontsize=15)
plt.hist(y,color='r',log='bool',align='left',bins=l,label='Python',histtype='step')
plt.legend()
plt.show()

# %%
y = [48, 67, 35, 46, 30, 93, 60, 29, 67, 94, 16, 26, 67, 48, 39, 88, 38, 25, 71, 15, 94, 88, 77, 67,
 84, 75, 14, 18, 92, 82, 34, 47, 48, 90, 42, 82, 72, 70, 79, 69, 45, 65, 81, 24, 45, 76, 46, 18,
 67, 72,]
plt.xlabel("Python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Histogram Plot in Matplotlib",fontsize=15)

plt.hist(y,color='y',edgecolor='k',label='Python',linewidth=6,bins=6,bottom=10)

plt.axvline(45,color = "g",label="line")

plt.legend(fontsize='large',loc="upper left")
plt.show()

# %%
y = [48, 67, 35, 46, 30, 93, 60, 29, 67, 94, 16, 26, 67, 48, 39, 88, 38, 25, 71, 15, 94, 88, 77, 67,
 84, 75, 14, 18, 92, 82, 34, 47, 48, 90, 42, 82, 72, 70, 79, 69, 45, 65, 81, 24, 45, 76, 46, 18,
 67, 72,]
plt.xlabel("Python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Histogram Plot in Matplotlib",fontsize=15)

plt.hist(y,color='y',edgecolor='k',label='Python',linewidth=6,bins=6,bottom=10)

plt.axvline(45,color = "g",label="line")

plt.legend(fontsize='large',loc="upper left")
plt.grid()
plt.show()

# %%
y = [48, 67, 35, 46, 30, 93, 60, 29, 67, 94, 16, 26, 67, 48, 39, 88, 38, 25, 71, 15, 94, 88, 77, 67,
 84, 75, 14, 18, 92, 82, 34, 47, 48, 90, 42, 82, 72, 70, 79, 69, 45, 65, 81, 24, 45, 76, 46, 18,
 67, 72,]
plt.xlabel("Python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Histogram Plot in Matplotlib",fontsize=15)
plt.hist(y,color='y',edgecolor='k',label='Python',linewidth=6,bins=6,bottom=10)
plt.legend(fontsize='large',loc="upper left")
plt.show()

# %%
y = [48, 67, 35, 46, 30, 93, 60, 29, 67, 94, 16, 26, 67, 48, 39, 88, 38, 25, 71, 15, 94, 88, 77, 67,
 84, 75, 14, 18, 92, 82, 34, 47, 48, 90, 42, 82, 72, 70, 79, 69, 45, 65, 81, 24, 45, 76, 46, 18,
 67, 72,]
plt.xlabel("Python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Histogram Plot in Matplotlib",fontsize=15)
plt.hist(y,color='m',edgecolor='k',label='Python',linewidth=6,bins=6,bottom=10,orientation='horizontal')
plt.legend(fontsize='large',loc="lower right")
plt.show()
